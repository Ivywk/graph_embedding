# %% [markdown]
# # Artificial Intelligence Nanodegree
#
# ## Convolutional Neural Networks
#
# ---
#
# In this notebook, we train a CNN to classify images from the CIFAR-10 database.
#
# ### 1. Load CIFAR-10 Database

# %%
#import keras
from tensorflow import keras
from keras.datasets import cifar10

# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# %%
print(type(x_train), len(x_train), len(y_train), y_train[1])
# Out:
# <class 'numpy.ndarray'> 50000 50000 [9]

# %% [markdown]
# ### 2. Visualize the First 24 Training Images

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Rescale the Images by Dividing Every Pixel in Every Image by 255

# %%
# rescale [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# ### 4.  Break Dataset into Training, Testing, and Validation Sets

# %%
from keras.utils import np_utils

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %% [markdown]
# ### 5. Define the Model Architecture

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 16)        208
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 32)        2080
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 8, 64)          8256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout (Dropout)            (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 500)               512500
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                5010
# =================================================================
# Total params: 528,054
# Trainable params: 528,054
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 6. Compile the Model

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', 
                  metrics=['accuracy'])

# %% [markdown]
# ### 7. Train the Model

# %%
from keras.callbacks import ModelCheckpoint   

# train the model
checkpointer = ModelCheckpoint(filepath='model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
hist = model.fit(x_train, y_train, batch_size=32, epochs=100,
          validation_data=(x_valid, y_valid), callbacks=[checkpointer], 
          verbose=2, shuffle=True)
# Out:
# Epoch 1/100
# 1407/1407 - 27s - loss: 1.5933 - accuracy: 0.4225 - val_loss: 1.5619 - val_accuracy: 0.4364
#
# Epoch 00001: val_loss improved from inf to 1.56186, saving model to model.weights.best.hdf5
# Epoch 2/100
# 1407/1407 - 7s - loss: 1.2680 - accuracy: 0.5503 - val_loss: 1.3780 - val_accuracy: 0.5226
#
# Epoch 00002: val_loss improved from 1.56186 to 1.37797, saving model to model.weights.best.hdf5
# Epoch 3/100
# 1407/1407 - 9s - loss: 1.1430 - accuracy: 0.5945 - val_loss: 1.0773 - val_accuracy: 0.6356
#
# Epoch 00003: val_loss improved from 1.37797 to 1.07727, saving model to model.weights.best.hdf5
# Epoch 4/100
# 1407/1407 - 9s - loss: 1.0794 - accuracy: 0.6241 - val_loss: 0.9911 - val_accuracy: 0.6598
#
# Epoch 00004: val_loss improved from 1.07727 to 0.99108, saving model to model.weights.best.hdf5
# Epoch 5/100
# 1407/1407 - 8s - loss: 1.0387 - accuracy: 0.6362 - val_loss: 1.0262 - val_accuracy: 0.6454
#
# Epoch 00005: val_loss did not improve from 0.99108
# Epoch 6/100
# 1407/1407 - 6s - loss: 1.0181 - accuracy: 0.6501 - val_loss: 1.0479 - val_accuracy: 0.6340
#
# Epoch 00006: val_loss did not improve from 0.99108
# Epoch 7/100
# 1407/1407 - 6s - loss: 1.0073 - accuracy: 0.6557 - val_loss: 1.0093 - val_accuracy: 0.6434
#
# Epoch 00007: val_loss did not improve from 0.99108
# Epoch 8/100
# 1407/1407 - 7s - loss: 0.9968 - accuracy: 0.6580 - val_loss: 1.0112 - val_accuracy: 0.6666
#
# Epoch 00008: val_loss did not improve from 0.99108
# Epoch 9/100
# 1407/1407 - 8s - loss: 0.9969 - accuracy: 0.6612 - val_loss: 1.0867 - val_accuracy: 0.6520
#
# Epoch 00009: val_loss did not improve from 0.99108
# Epoch 10/100
# 1407/1407 - 5s - loss: 1.0018 - accuracy: 0.6621 - val_loss: 1.2214 - val_accuracy: 0.6278
#
# Epoch 00010: val_loss did not improve from 0.99108
# Epoch 11/100
# 1407/1407 - 5s - loss: 1.0106 - accuracy: 0.6626 - val_loss: 1.0012 - val_accuracy: 0.7036
#
# Epoch 00011: val_loss did not improve from 0.99108
# Epoch 12/100
# 1407/1407 - 6s - loss: 1.0304 - accuracy: 0.6537 - val_loss: 0.9603 - val_accuracy: 0.6692
#
# Epoch 00012: val_loss improved from 0.99108 to 0.96034, saving model to model.weights.best.hdf5
# Epoch 13/100
# 1407/1407 - 5s - loss: 1.0485 - accuracy: 0.6520 - val_loss: 1.2565 - val_accuracy: 0.5654
#
# Epoch 00013: val_loss did not improve from 0.96034
# Epoch 14/100
# 1407/1407 - 6s - loss: 1.0673 - accuracy: 0.6444 - val_loss: 1.0048 - val_accuracy: 0.6728
#
# Epoch 00014: val_loss did not improve from 0.96034
# Epoch 15/100
# 1407/1407 - 8s - loss: 1.0908 - accuracy: 0.6376 - val_loss: 1.2141 - val_accuracy: 0.6226
#
# Epoch 00015: val_loss did not improve from 0.96034
# Epoch 16/100
# 1407/1407 - 6s - loss: 1.1279 - accuracy: 0.6276 - val_loss: 1.5972 - val_accuracy: 0.6278
#
# Epoch 00016: val_loss did not improve from 0.96034
# Epoch 17/100
# 1407/1407 - 4s - loss: 1.1498 - accuracy: 0.6181 - val_loss: 1.0583 - val_accuracy: 0.6706
#
# Epoch 00017: val_loss did not improve from 0.96034
# Epoch 18/100
# 1407/1407 - 9s - loss: 1.1611 - accuracy: 0.6158 - val_loss: 1.1387 - val_accuracy: 0.6410
#
# Epoch 00018: val_loss did not improve from 0.96034
# Epoch 19/100
# 1407/1407 - 8s - loss: 1.1779 - accuracy: 0.6137 - val_loss: 1.2094 - val_accuracy: 0.6516
#
# Epoch 00019: val_loss did not improve from 0.96034
# Epoch 20/100
# 1407/1407 - 9s - loss: 1.2007 - accuracy: 0.6072 - val_loss: 1.1742 - val_accuracy: 0.5814
#
# Epoch 00020: val_loss did not improve from 0.96034
# Epoch 21/100
# 1407/1407 - 8s - loss: 1.2168 - accuracy: 0.5977 - val_loss: 1.3429 - val_accuracy: 0.5992
#
# Epoch 00021: val_loss did not improve from 0.96034
# Epoch 22/100
# 1407/1407 - 7s - loss: 1.2219 - accuracy: 0.5990 - val_loss: 1.1555 - val_accuracy: 0.6344
#
# Epoch 00022: val_loss did not improve from 0.96034
# Epoch 23/100
# 1407/1407 - 9s - loss: 1.2472 - accuracy: 0.5883 - val_loss: 1.2681 - val_accuracy: 0.6042
#
# Epoch 00023: val_loss did not improve from 0.96034
# Epoch 24/100
# 1407/1407 - 9s - loss: 1.2736 - accuracy: 0.5797 - val_loss: 1.3865 - val_accuracy: 0.4988
#
# Epoch 00024: val_loss did not improve from 0.96034
# Epoch 25/100
# 1407/1407 - 9s - loss: 1.2777 - accuracy: 0.5762 - val_loss: 1.0622 - val_accuracy: 0.6408
#
# Epoch 00025: val_loss did not improve from 0.96034
# Epoch 26/100
# 1407/1407 - 9s - loss: 1.3071 - accuracy: 0.5698 - val_loss: 1.0891 - val_accuracy: 0.6212
#
# Epoch 00026: val_loss did not improve from 0.96034
# Epoch 27/100
# 1407/1407 - 7s - loss: 1.3152 - accuracy: 0.5675 - val_loss: 1.1944 - val_accuracy: 0.5788
#
# Epoch 00027: val_loss did not improve from 0.96034
# Epoch 28/100
# 1407/1407 - 9s - loss: 1.3217 - accuracy: 0.5643 - val_loss: 1.5281 - val_accuracy: 0.5044
#
# Epoch 00028: val_loss did not improve from 0.96034
# Epoch 29/100
# 1407/1407 - 9s - loss: 1.3326 - accuracy: 0.5568 - val_loss: 1.1853 - val_accuracy: 0.6142
#
# Epoch 00029: val_loss did not improve from 0.96034
# Epoch 30/100
# 1407/1407 - 9s - loss: 1.3332 - accuracy: 0.5561 - val_loss: 1.1866 - val_accuracy: 0.6038
#
# Epoch 00030: val_loss did not improve from 0.96034
# Epoch 31/100
# 1407/1407 - 9s - loss: 1.3596 - accuracy: 0.5535 - val_loss: 1.5305 - val_accuracy: 0.4532
#
# Epoch 00031: val_loss did not improve from 0.96034
# Epoch 32/100
# 1407/1407 - 9s - loss: 1.3794 - accuracy: 0.5410 - val_loss: 1.4125 - val_accuracy: 0.5672
#
# Epoch 00032: val_loss did not improve from 0.96034
# Epoch 33/100
# 1407/1407 - 9s - loss: 1.3941 - accuracy: 0.5394 - val_loss: 1.2582 - val_accuracy: 0.5868
#
# Epoch 00033: val_loss did not improve from 0.96034
# Epoch 34/100
# 1407/1407 - 10s - loss: 1.4097 - accuracy: 0.5327 - val_loss: 1.8958 - val_accuracy: 0.4522
#
# Epoch 00034: val_loss did not improve from 0.96034
# Epoch 35/100
# 1407/1407 - 9s - loss: 1.4106 - accuracy: 0.5300 - val_loss: 1.9431 - val_accuracy: 0.4970
#
# Epoch 00035: val_loss did not improve from 0.96034
# Epoch 36/100
# 1407/1407 - 9s - loss: 1.4231 - accuracy: 0.5256 - val_loss: 1.2387 - val_accuracy: 0.5684
#
# Epoch 00036: val_loss did not improve from 0.96034
# Epoch 37/100
# 1407/1407 - 8s - loss: 1.4414 - accuracy: 0.5171 - val_loss: 1.4099 - val_accuracy: 0.4942
#
# Epoch 00037: val_loss did not improve from 0.96034
# Epoch 38/100
# 1407/1407 - 7s - loss: 1.4474 - accuracy: 0.5156 - val_loss: 1.2741 - val_accuracy: 0.5620
#
# Epoch 00038: val_loss did not improve from 0.96034
# Epoch 39/100
# 1407/1407 - 9s - loss: 1.4583 - accuracy: 0.5104 - val_loss: 1.7445 - val_accuracy: 0.4506
#
# Epoch 00039: val_loss did not improve from 0.96034
# Epoch 40/100
# 1407/1407 - 8s - loss: 1.4642 - accuracy: 0.5116 - val_loss: 1.3703 - val_accuracy: 0.5500
#
# Epoch 00040: val_loss did not improve from 0.96034
# Epoch 41/100
# 1407/1407 - 6s - loss: 1.4860 - accuracy: 0.5048 - val_loss: 1.1503 - val_accuracy: 0.6016
#
# Epoch 00041: val_loss did not improve from 0.96034
# Epoch 42/100
# 1407/1407 - 4s - loss: 1.5006 - accuracy: 0.4996 - val_loss: 1.3675 - val_accuracy: 0.5360
#
# Epoch 00042: val_loss did not improve from 0.96034
# Epoch 43/100
# 1407/1407 - 7s - loss: 1.5097 - accuracy: 0.4934 - val_loss: 2.5023 - val_accuracy: 0.4574
#
# Epoch 00043: val_loss did not improve from 0.96034
# Epoch 44/100
# 1407/1407 - 8s - loss: 1.5374 - accuracy: 0.4874 - val_loss: 1.3415 - val_accuracy: 0.5556
#
# Epoch 00044: val_loss did not improve from 0.96034
# Epoch 45/100
# 1407/1407 - 8s - loss: 1.5621 - accuracy: 0.4767 - val_loss: 1.5072 - val_accuracy: 0.5202
#
# Epoch 00045: val_loss did not improve from 0.96034
# Epoch 46/100
# 1407/1407 - 6s - loss: 1.5597 - accuracy: 0.4759 - val_loss: 1.8066 - val_accuracy: 0.3884
#
# Epoch 00046: val_loss did not improve from 0.96034
# Epoch 47/100
# 1407/1407 - 8s - loss: 1.5768 - accuracy: 0.4669 - val_loss: 1.4667 - val_accuracy: 0.4880
#
# Epoch 00047: val_loss did not improve from 0.96034
# Epoch 48/100
# 1407/1407 - 9s - loss: 1.5984 - accuracy: 0.4611 - val_loss: 1.9909 - val_accuracy: 0.4230
#
# Epoch 00048: val_loss did not improve from 0.96034
# Epoch 49/100
# 1407/1407 - 6s - loss: 1.5842 - accuracy: 0.4656 - val_loss: 1.3042 - val_accuracy: 0.5362
#
# Epoch 00049: val_loss did not improve from 0.96034
# Epoch 50/100
# 1407/1407 - 8s - loss: 1.6198 - accuracy: 0.4513 - val_loss: 1.3544 - val_accuracy: 0.5112
#
# Epoch 00050: val_loss did not improve from 0.96034
# Epoch 51/100
# 1407/1407 - 7s - loss: 1.6078 - accuracy: 0.4543 - val_loss: 1.7308 - val_accuracy: 0.5076
#
# Epoch 00051: val_loss did not improve from 0.96034
# Epoch 52/100
# 1407/1407 - 5s - loss: 1.6220 - accuracy: 0.4462 - val_loss: 2.2536 - val_accuracy: 0.4672
# Epoch 00052: val_loss did not improve from 0.96034
# Epoch 53/100
# 1407/1407 - 5s - loss: 1.6433 - accuracy: 0.4402 - val_loss: 1.7463 - val_accuracy: 0.4482
#
# Epoch 00053: val_loss did not improve from 0.96034
# Epoch 54/100
# 1407/1407 - 6s - loss: 1.6531 - accuracy: 0.4367 - val_loss: 2.5591 - val_accuracy: 0.3666
#
# Epoch 00054: val_loss did not improve from 0.96034
# Epoch 55/100
# 1407/1407 - 8s - loss: 1.6362 - accuracy: 0.4414 - val_loss: 1.5146 - val_accuracy: 0.5042
#
# Epoch 00055: val_loss did not improve from 0.96034
# Epoch 56/100
# 1407/1407 - 7s - loss: 1.6498 - accuracy: 0.4328 - val_loss: 1.4756 - val_accuracy: 0.4646
#
# Epoch 00056: val_loss did not improve from 0.96034
# Epoch 57/100
# 1407/1407 - 6s - loss: 1.6562 - accuracy: 0.4380 - val_loss: 1.3383 - val_accuracy: 0.5396
#
# Epoch 00057: val_loss did not improve from 0.96034
# Epoch 58/100
# 1407/1407 - 8s - loss: 1.6562 - accuracy: 0.4350 - val_loss: 1.5487 - val_accuracy: 0.4844
#
# Epoch 00058: val_loss did not improve from 0.96034
# Epoch 59/100
# 1407/1407 - 9s - loss: 1.6584 - accuracy: 0.4312 - val_loss: 1.8730 - val_accuracy: 0.3828
#
# Epoch 00059: val_loss did not improve from 0.96034
# Epoch 60/100
# 1407/1407 - 9s - loss: 1.6624 - accuracy: 0.4270 - val_loss: 2.3375 - val_accuracy: 0.3984
#
# Epoch 00060: val_loss did not improve from 0.96034
# Epoch 61/100
# 1407/1407 - 9s - loss: 1.6694 - accuracy: 0.4232 - val_loss: 1.4563 - val_accuracy: 0.4718
#
# Epoch 00061: val_loss did not improve from 0.96034
# Epoch 62/100
# 1407/1407 - 9s - loss: 1.6727 - accuracy: 0.4239 - val_loss: 1.3694 - val_accuracy: 0.5100
#
# Epoch 00062: val_loss did not improve from 0.96034
# Epoch 63/100
# 1407/1407 - 9s - loss: 1.6811 - accuracy: 0.4245 - val_loss: 1.3801 - val_accuracy: 0.5172
#
# Epoch 00063: val_loss did not improve from 0.96034
# Epoch 64/100
# 1407/1407 - 9s - loss: 1.6766 - accuracy: 0.4237 - val_loss: 1.4758 - val_accuracy: 0.4602
#
# Epoch 00064: val_loss did not improve from 0.96034
# Epoch 65/100
# 1407/1407 - 8s - loss: 1.6972 - accuracy: 0.4131 - val_loss: 1.5292 - val_accuracy: 0.4226
#
# Epoch 00065: val_loss did not improve from 0.96034
# Epoch 66/100
# 1407/1407 - 8s - loss: 1.7003 - accuracy: 0.4163 - val_loss: 1.4256 - val_accuracy: 0.4902
#
# Epoch 00066: val_loss did not improve from 0.96034
# Epoch 67/100
# 1407/1407 - 7s - loss: 1.6840 - accuracy: 0.4189 - val_loss: 1.4449 - val_accuracy: 0.4840
#
# Epoch 00067: val_loss did not improve from 0.96034
# Epoch 68/100
# 1407/1407 - 7s - loss: 1.6777 - accuracy: 0.4197 - val_loss: 1.4034 - val_accuracy: 0.4956
#
# Epoch 00068: val_loss did not improve from 0.96034
# Epoch 69/100
# 1407/1407 - 5s - loss: 1.7022 - accuracy: 0.4106 - val_loss: 1.4959 - val_accuracy: 0.4752
#
# Epoch 00069: val_loss did not improve from 0.96034
# Epoch 70/100
# 1407/1407 - 6s - loss: 1.6991 - accuracy: 0.4136 - val_loss: 1.5577 - val_accuracy: 0.4378
#
# Epoch 00070: val_loss did not improve from 0.96034
# Epoch 71/100
# 1407/1407 - 5s - loss: 1.7160 - accuracy: 0.4057 - val_loss: 1.9883 - val_accuracy: 0.3230
#
# Epoch 00071: val_loss did not improve from 0.96034
# Epoch 72/100
# 1407/1407 - 6s - loss: 1.7175 - accuracy: 0.4050 - val_loss: 1.4041 - val_accuracy: 0.5306
#
# Epoch 00072: val_loss did not improve from 0.96034
# Epoch 73/100
# 1407/1407 - 7s - loss: 1.7263 - accuracy: 0.4024 - val_loss: 1.7597 - val_accuracy: 0.4236
#
# Epoch 00073: val_loss did not improve from 0.96034
# Epoch 74/100
# 1407/1407 - 8s - loss: 1.7237 - accuracy: 0.3980 - val_loss: 1.6947 - val_accuracy: 0.4186
#
# Epoch 00074: val_loss did not improve from 0.96034
# Epoch 75/100
# 1407/1407 - 6s - loss: 1.7135 - accuracy: 0.4004 - val_loss: 1.5052 - val_accuracy: 0.4754
#
# Epoch 00075: val_loss did not improve from 0.96034
# Epoch 76/100
# 1407/1407 - 7s - loss: 1.7246 - accuracy: 0.3973 - val_loss: 1.3787 - val_accuracy: 0.5088
#
# Epoch 00076: val_loss did not improve from 0.96034
# Epoch 77/100
# 1407/1407 - 6s - loss: 1.7235 - accuracy: 0.3958 - val_loss: 1.6600 - val_accuracy: 0.4176
#
# Epoch 00077: val_loss did not improve from 0.96034
# Epoch 78/100
# 1407/1407 - 8s - loss: 1.7203 - accuracy: 0.3960 - val_loss: 1.4111 - val_accuracy: 0.4960
#
# Epoch 00078: val_loss did not improve from 0.96034
# Epoch 79/100
# 1407/1407 - 8s - loss: 1.7374 - accuracy: 0.3958 - val_loss: 1.4680 - val_accuracy: 0.4796
#
# Epoch 00079: val_loss did not improve from 0.96034
# Epoch 80/100
# 1407/1407 - 5s - loss: 1.7416 - accuracy: 0.3863 - val_loss: 1.5983 - val_accuracy: 0.4356
#
# Epoch 00080: val_loss did not improve from 0.96034
# Epoch 81/100
# 1407/1407 - 8s - loss: 1.7337 - accuracy: 0.3981 - val_loss: 1.5310 - val_accuracy: 0.4698
#
# Epoch 00081: val_loss did not improve from 0.96034
# Epoch 82/100
# 1407/1407 - 7s - loss: 1.7394 - accuracy: 0.3950 - val_loss: 2.0560 - val_accuracy: 0.3268
#
# Epoch 00082: val_loss did not improve from 0.96034
# Epoch 83/100
# 1407/1407 - 8s - loss: 1.7296 - accuracy: 0.3934 - val_loss: 2.3818 - val_accuracy: 0.3548
#
# Epoch 00083: val_loss did not improve from 0.96034
# Epoch 84/100
# 1407/1407 - 7s - loss: 1.7537 - accuracy: 0.3829 - val_loss: 1.5356 - val_accuracy: 0.4512
#
# Epoch 00084: val_loss did not improve from 0.96034
# Epoch 85/100
# 1407/1407 - 4s - loss: 1.7433 - accuracy: 0.3879 - val_loss: 1.3839 - val_accuracy: 0.5274
#
# Epoch 00085: val_loss did not improve from 0.96034
# Epoch 86/100
# 1407/1407 - 6s - loss: 1.7491 - accuracy: 0.3833 - val_loss: 1.5749 - val_accuracy: 0.4424
#
# Epoch 00086: val_loss did not improve from 0.96034
# Epoch 87/100
# 1407/1407 - 7s - loss: 1.7527 - accuracy: 0.3776 - val_loss: 1.6838 - val_accuracy: 0.4222
#
# Epoch 00087: val_loss did not improve from 0.96034
# Epoch 88/100
# 1407/1407 - 6s - loss: 1.7677 - accuracy: 0.3767 - val_loss: 1.9965 - val_accuracy: 0.3784
#
# Epoch 00088: val_loss did not improve from 0.96034
# Epoch 89/100
# 1407/1407 - 7s - loss: 1.7589 - accuracy: 0.3770 - val_loss: 1.6194 - val_accuracy: 0.4180
#
# Epoch 00089: val_loss did not improve from 0.96034
# Epoch 90/100
# 1407/1407 - 7s - loss: 1.7738 - accuracy: 0.3714 - val_loss: 1.6240 - val_accuracy: 0.4002
#
# Epoch 00090: val_loss did not improve from 0.96034
# Epoch 91/100
# 1407/1407 - 9s - loss: 1.7837 - accuracy: 0.3667 - val_loss: 1.5240 - val_accuracy: 0.4612
#
# Epoch 00091: val_loss did not improve from 0.96034
# Epoch 92/100
# 1407/1407 - 8s - loss: 1.7977 - accuracy: 0.3611 - val_loss: 1.5917 - val_accuracy: 0.4424
#
# Epoch 00092: val_loss did not improve from 0.96034
# Epoch 93/100
# 1407/1407 - 6s - loss: 1.7969 - accuracy: 0.3619 - val_loss: 2.4334 - val_accuracy: 0.2834
#
# Epoch 00093: val_loss did not improve from 0.96034
# Epoch 94/100
# 1407/1407 - 8s - loss: 1.8047 - accuracy: 0.3597 - val_loss: 1.5067 - val_accuracy: 0.4654
#
# Epoch 00094: val_loss did not improve from 0.96034
# Epoch 95/100
# 1407/1407 - 10s - loss: 1.8141 - accuracy: 0.3566 - val_loss: 1.6270 - val_accuracy: 0.4210
#
# Epoch 00095: val_loss did not improve from 0.96034
# Epoch 96/100
# 1407/1407 - 7s - loss: 1.8204 - accuracy: 0.3510 - val_loss: 1.7338 - val_accuracy: 0.3582
#
# Epoch 00096: val_loss did not improve from 0.96034
# Epoch 97/100
# 1407/1407 - 7s - loss: 1.8249 - accuracy: 0.3521 - val_loss: 1.6019 - val_accuracy: 0.4104
#
# Epoch 00097: val_loss did not improve from 0.96034
# Epoch 98/100
# 1407/1407 - 8s - loss: 1.8202 - accuracy: 0.3482 - val_loss: 1.7656 - val_accuracy: 0.3456
#
# Epoch 00098: val_loss did not improve from 0.96034
# Epoch 99/100
# 1407/1407 - 6s - loss: 1.8363 - accuracy: 0.3483 - val_loss: 1.6275 - val_accuracy: 0.4314
#
# Epoch 00099: val_loss did not improve from 0.96034
# Epoch 100/100
# 1407/1407 - 6s - loss: 1.8299 - accuracy: 0.3472 - val_loss: 3.2052 - val_accuracy: 0.2486
#
# Epoch 00100: val_loss did not improve from 0.96034

# %% [markdown]
# ### 8. Load the Model with the Best Validation Accuracy

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('model.weights.best.hdf5')

# %% [markdown]
# ### 9. Calculate Classification Accuracy on Test Set

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.6732000112533569

# %% [markdown]
# ### 10. Visualize Some Predictions
#
# This may give you some insight into why the network is misclassifying certain objects.

# %%
# get predictions on the test set
y_hat = model.predict(x_test)

# define text labels (source: https://www.cs.toronto.edu/~kriz/cifar.html)
cifar10_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# plot a random sample of test images, their predicted labels, and ground truth
fig = plt.figure(figsize=(20, 8))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=32, replace=False)):
    ax = fig.add_subplot(4, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(cifar10_labels[pred_idx], cifar10_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))
